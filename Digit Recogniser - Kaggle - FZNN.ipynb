# %%
import numpy as np
import IPython.display

# %%
class Conv:
    def __init__(self, num_filters):
        self.num_filters = num_filters
        self.filters = np.random.randn(num_filters, 3, 3)/9
    def iterate_regions(self, image):
        h,w = image.shape
        for i in range(h-2):
            for j in range(w-2):
                im_region = image[i:(i+3), j:(j+3)]
                yield im_region, i, j
                
    def forward(self, input):
        self.last_input = input
        h,w = input.shape
        output = np.zeros((h-2, w-2, self.num_filters))
        for im_regions, i, j in self.iterate_regions(input):
            output[i, j] = np.sum(im_regions * self.filters, axis=(1,2))
        return output
    
    def backprop(self, d_l_d_out, learn_rate):
        d_l_d_filters = np.zeros(self.filters.shape)
        for im_region, i, j in self.iterate_regions(self.last_input):
            for f in range(self.num_filters):
                d_l_d_filters[f] += d_l_d_out[i,j,f] * im_region
        self.filters -= learn_rate * d_l_d_filters
        return None

# %%
class MaxPool:
    def iterate_regions(self, image):
        h, w, _ = image.shape  
        new_h = h // 2
        new_w = w // 2
        for i in range(new_h):
            for j in range(new_w):
                im_region = image[(i*2):(i*2+2), (j*2):(j*2+2)]
                yield im_region, i, j
    def forward(self, input):
        self.last_input = input
        h, w, num_filters = input.shape
        output = np.zeros((h//2, w//2, num_filters))
        for im_region, i, j in self.iterate_regions(input):
            output[i,j] = np.amax(im_region,axis=(0,1))
        return output
    
    def backprop(self, d_l_d_out):
        d_l_d_input = np.zeros(self.last_input.shape)
        for im_region, i, j in self.iterate_regions(self.last_input):
            h, w, f = im_region.shape
            amax = np.amax(im_region, axis=(0,1))
            for i2 in range(h):
                for j2 in range(w):
                    for f2 in range(f):
                        #if the pixel was the max value, copy the gradient to it
                        if(im_region[i2,j2,f2] == amax[f2]):
                            d_l_d_input[i*2+i2, j*2+j2 ,f2] = d_l_d_out[i, j, f2]
                            break;
        return d_l_d_input

# %%
class Softmax:
    def __init__(self, input_len, nodes):
        # We divide by input_len to reduce the variance of our initial values
        self.weights = np.random.randn(input_len, nodes)/input_len
        self.biases = np.zeros(nodes)
    def forward(self, input):
        self.last_input_shape = input.shape
        input = input.flatten()
        self.last_input = input
        input_len, nodes = self.weights.shape
        totals = np.dot(input, self.weights) + self.biases
        self.last_totals = totals
        exp = np.exp(totals)
        return(exp/np.sum(exp, axis=0)) 
    
    def backprop(self, d_l_d_out, learn_rate):
        for i, gradient in enumerate(d_l_d_out):
            if(gradient == 0):
                continue
            t_exp = np.exp(self.last_totals)
            S = np.sum(t_exp)
            d_out_d_t = -t_exp[i] * t_exp/ (S**2)
            d_out_d_t[i] = t_exp[i] * (S-t_exp[i]) /(S**2)
            
            d_t_d_w = self.last_input
            d_t_d_b = 1
            d_t_d_inputs = self.weights
            
            d_l_d_t = gradient * d_out_d_t
            
            d_l_d_w = d_t_d_w[np.newaxis].T @ d_l_d_t[np.newaxis]
            d_l_d_b = d_l_d_t * d_t_d_b  
            d_l_d_inputs = d_t_d_inputs @ d_l_d_t
            
            self.weights -= learn_rate * d_l_d_w
            self.biases -= learn_rate * d_l_d_b
            return d_l_d_inputs.reshape(self.last_input_shape)

# %%
train_file = 'E:/Curious Dev B/Kaggle/train.csv'
test_file = 'E:/Curious Dev B/Kaggle/test.csv'

def get_data_with_label(file):
    fh = open(file)
    ct = 0
    labels = []
    images = []
    for line in fh:
        ct += 1
        if ct == 1:
            continue
        pix_str = line.split(',')
        labels.append(float(pix_str[0]))
        pix_np = np.asarray(pix_str[1:], dtype = float)
        pix_np_split = np.array_split(pix_np, 28)
        pix_np_split_asarray = np.asarray(pix_np_split, dtype = 'int')
        images.append(pix_np_split_asarray)
    return images, labels

def get_data(file):
    fh = open(file)
    ct = 0
    images = []
    for line in fh:
        ct += 1
        if ct == 1:
            continue
        pix_str = line.split(',')
        pix_np = np.asarray(pix_str, dtype = float)
        pix_np_split = np.array_split(pix_np, 28)
        pix_np_split_asarray = np.asarray(pix_np_split, dtype = 'int')
        images.append(pix_np_split_asarray)
    return images

tr_img_list, tr_lb_list = get_data_with_label(train_file)
t_img_list = get_data(test_file)

training_images = np.asarray(tr_img_list)
training_labels = np.asarray(tr_lb_list)
testing_images = np.asarray(t_img_list)

print(training_images.shape)
print(training_labels.shape)
print(testing_images.shape)

training_labels = np.asarray(training_labels, dtype = 'int')
# Out:
# (42000, 28, 28)
# (42000,)
# (28000, 28, 28)

# %%
conv = Conv(8)
pool = MaxPool()
softmax = Softmax(13 * 13 * 8, 10)

def forward(image, label):
    out = conv.forward((image/255) - 0.5)
    out = pool.forward(out)
    out = softmax.forward(out)
    loss = -np.log(out[label])
    acc = 1 if(np.argmax(out) == label) else 0
    
    return out, loss, acc

def train(im, label, lr=0.005):
    out,loss,acc = forward(im, label)
    
    gradient = np.zeros(10)
    gradient[label] = -1/out[label]
    
    gradient = softmax.backprop(gradient, lr)
    gradient = pool.backprop(gradient)
    gradient = conv.backprop(gradient, lr)
    
    return loss, acc
    
print('Training Starts....')

for epoch in range(3):
    print('----EPOCH %d ---'%(epoch+1))

    loss = 0
    num_correct = 0
    for i, (im, label) in enumerate(zip(training_images, training_labels)):
        if(i>0 and i %1000 == 999):
            print('[Step %d] Past 100 steps: Average Loss %.3f | Accuracy: %d%%' %(i + 1, loss / 100, num_correct))
            loss = 0
            num_correct = 0
        l, acc = train(im, label)
        loss += l
        num_correct += acc
# Out:
# MNIST CNN initialized
# ----EPOCH 1 ---
# [Step 100] Past 100 steps: Average Loss 2.243 | Accuracy: 16%
# [Step 200] Past 100 steps: Average Loss 2.239 | Accuracy: 26%
# [Step 300] Past 100 steps: Average Loss 2.002 | Accuracy: 37%
# [Step 400] Past 100 steps: Average Loss 1.879 | Accuracy: 48%
# [Step 500] Past 100 steps: Average Loss 1.511 | Accuracy: 66%
# [Step 600] Past 100 steps: Average Loss 1.229 | Accuracy: 66%
# [Step 700] Past 100 steps: Average Loss 1.098 | Accuracy: 68%
# [Step 800] Past 100 steps: Average Loss 0.856 | Accuracy: 70%
# [Step 900] Past 100 steps: Average Loss 0.838 | Accuracy: 75%
# [Step 1000] Past 100 steps: Average Loss 0.692 | Accuracy: 79%
# [Step 1100] Past 100 steps: Average Loss 0.706 | Accuracy: 78%
# [Step 1200] Past 100 steps: Average Loss 0.713 | Accuracy: 77%
# [Step 1300] Past 100 steps: Average Loss 0.562 | Accuracy: 84%
# [Step 1400] Past 100 steps: Average Loss 0.562 | Accuracy: 82%
# [Step 1500] Past 100 steps: Average Loss 0.475 | Accuracy: 86%
# [Step 1600] Past 100 steps: Average Loss 0.466 | Accuracy: 85%
# [Step 1700] Past 100 steps: Average Loss 0.531 | Accuracy: 88%
# [Step 1800] Past 100 steps: Average Loss 0.715 | Accuracy: 82%
# [Step 1900] Past 100 steps: Average Loss 0.524 | Accuracy: 84%
# [Step 2000] Past 100 steps: Average Loss 0.456 | Accuracy: 85%
# [Step 2100] Past 100 steps: Average Loss 0.557 | Accuracy: 85%
# [Step 2200] Past 100 steps: Average Loss 0.512 | Accuracy: 82%
# [Step 2300] Past 100 steps: Average Loss 0.473 | Accuracy: 89%
# [Step 2400] Past 100 steps: Average Loss 0.540 | Accuracy: 84%
# [Step 2500] Past 100 steps: Average Loss 0.460 | Accuracy: 84%
# [Step 2600] Past 100 steps: Average Loss 0.493 | Accuracy: 88%
# [Step 2700] Past 100 steps: Average Loss 0.345 | Accuracy: 89%
# [Step 2800] Past 100 steps: Average Loss 0.481 | Accuracy: 85%
# [Step 2900] Past 100 steps: Average Loss 0.386 | Accuracy: 85%
# [Step 3000] Past 100 steps: Average Loss 0.586 | Accuracy: 79%
# [Step 3100] Past 100 steps: Average Loss 0.439 | Accuracy: 88%
# [Step 3200] Past 100 steps: Average Loss 0.221 | Accuracy: 93%
# [Step 3300] Past 100 steps: Average Loss 0.555 | Accuracy: 88%
# [Step 3400] Past 100 steps: Average Loss 0.504 | Accuracy: 83%
# [Step 3500] Past 100 steps: Average Loss 0.412 | Accuracy: 89%
# [Step 3600] Past 100 steps: Average Loss 0.618 | Accuracy: 83%
# [Step 3700] Past 100 steps: Average Loss 0.538 | Accuracy: 81%
# [Step 3800] Past 100 steps: Average Loss 0.609 | Accuracy: 79%
# [Step 3900] Past 100 steps: Average Loss 0.428 | Accuracy: 85%
# [Step 4000] Past 100 steps: Average Loss 0.328 | Accuracy: 91%
# [Step 4100] Past 100 steps: Average Loss 0.365 | Accuracy: 91%
# [Step 4200] Past 100 steps: Average Loss 0.380 | Accuracy: 93%
# [Step 4300] Past 100 steps: Average Loss 0.323 | Accuracy: 90%
# [Step 4400] Past 100 steps: Average Loss 0.383 | Accuracy: 87%
# [Step 4500] Past 100 steps: Average Loss 0.509 | Accuracy: 83%
# [Step 4600] Past 100 steps: Average Loss 0.232 | Accuracy: 94%
# [Step 4700] Past 100 steps: Average Loss 0.569 | Accuracy: 84%
# [Step 4800] Past 100 steps: Average Loss 0.398 | Accuracy: 86%
# [Step 4900] Past 100 steps: Average Loss 0.507 | Accuracy: 85%
# [Step 5000] Past 100 steps: Average Loss 0.353 | Accuracy: 86%
# [Step 5100] Past 100 steps: Average Loss 0.416 | Accuracy: 88%
# [Step 5200] Past 100 steps: Average Loss 0.393 | Accuracy: 86%
# [Step 5300] Past 100 steps: Average Loss 0.414 | Accuracy: 86%
# [Step 5400] Past 100 steps: Average Loss 0.521 | Accuracy: 84%
# [Step 5500] Past 100 steps: Average Loss 0.493 | Accuracy: 85%
# [Step 5600] Past 100 steps: Average Loss 0.310 | Accuracy: 90%
# [Step 5700] Past 100 steps: Average Loss 0.330 | Accuracy: 92%
# [Step 5800] Past 100 steps: Average Loss 0.425 | Accuracy: 87%
# [Step 5900] Past 100 steps: Average Loss 0.384 | Accuracy: 90%
# [Step 6000] Past 100 steps: Average Loss 0.446 | Accuracy: 88%
# [Step 6100] Past 100 steps: Average Loss 0.352 | Accuracy: 89%
# [Step 6200] Past 100 steps: Average Loss 0.561 | Accuracy: 84%
# [Step 6300] Past 100 steps: Average Loss 0.490 | Accuracy: 82%
# [Step 6400] Past 100 steps: Average Loss 0.345 | Accuracy: 88%
# [Step 6500] Past 100 steps: Average Loss 0.272 | Accuracy: 94%
# [Step 6600] Past 100 steps: Average Loss 0.394 | Accuracy: 88%
# [Step 6700] Past 100 steps: Average Loss 0.522 | Accuracy: 83%
# [Step 6800] Past 100 steps: Average Loss 0.293 | Accuracy: 93%
# [Step 6900] Past 100 steps: Average Loss 0.407 | Accuracy: 87%
# [Step 7000] Past 100 steps: Average Loss 0.429 | Accuracy: 83%
# [Step 7100] Past 100 steps: Average Loss 0.273 | Accuracy: 93%
# [Step 7200] Past 100 steps: Average Loss 0.416 | Accuracy: 86%
# [Step 7300] Past 100 steps: Average Loss 0.364 | Accuracy: 91%
# [Step 7400] Past 100 steps: Average Loss 0.381 | Accuracy: 85%
# [Step 7500] Past 100 steps: Average Loss 0.354 | Accuracy: 90%
# [Step 7600] Past 100 steps: Average Loss 0.561 | Accuracy: 86%
# [Step 7700] Past 100 steps: Average Loss 0.577 | Accuracy: 85%
# [Step 7800] Past 100 steps: Average Loss 0.526 | Accuracy: 84%
# [Step 7900] Past 100 steps: Average Loss 0.264 | Accuracy: 91%
# [Step 8000] Past 100 steps: Average Loss 0.380 | Accuracy: 89%
# [Step 8100] Past 100 steps: Average Loss 0.285 | Accuracy: 91%
# [Step 8200] Past 100 steps: Average Loss 0.450 | Accuracy: 87%
# [Step 8300] Past 100 steps: Average Loss 0.374 | Accuracy: 87%
# [Step 8400] Past 100 steps: Average Loss 0.446 | Accuracy: 85%
# [Step 8500] Past 100 steps: Average Loss 0.352 | Accuracy: 86%
# [Step 8600] Past 100 steps: Average Loss 0.173 | Accuracy: 94%
# [Step 8700] Past 100 steps: Average Loss 0.518 | Accuracy: 87%
# [Step 8800] Past 100 steps: Average Loss 0.285 | Accuracy: 93%
# [Step 8900] Past 100 steps: Average Loss 0.440 | Accuracy: 86%
# [Step 9000] Past 100 steps: Average Loss 0.304 | Accuracy: 92%
# [Step 9100] Past 100 steps: Average Loss 0.322 | Accuracy: 92%
# [Step 9200] Past 100 steps: Average Loss 0.352 | Accuracy: 90%
# [Step 9300] Past 100 steps: Average Loss 0.229 | Accuracy: 91%
# [Step 9400] Past 100 steps: Average Loss 0.355 | Accuracy: 89%
# [Step 9500] Past 100 steps: Average Loss 0.434 | Accuracy: 90%
# [Step 9600] Past 100 steps: Average Loss 0.458 | Accuracy: 83%
# [Step 9700] Past 100 steps: Average Loss 0.254 | Accuracy: 90%
# [Step 9800] Past 100 steps: Average Loss 0.467 | Accuracy: 88%
# [Step 9900] Past 100 steps: Average Loss 0.304 | Accuracy: 90%
# [Step 10000] Past 100 steps: Average Loss 0.292 | Accuracy: 94%
# [Step 10100] Past 100 steps: Average Loss 0.156 | Accuracy: 95%
# [Step 10200] Past 100 steps: Average Loss 0.311 | Accuracy: 90%
# [Step 10300] Past 100 steps: Average Loss 0.380 | Accuracy: 86%
# [Step 10400] Past 100 steps: Average Loss 0.454 | Accuracy: 90%
# [Step 10500] Past 100 steps: Average Loss 0.227 | Accuracy: 94%
# [Step 10600] Past 100 steps: Average Loss 0.363 | Accuracy: 87%
# [Step 10700] Past 100 steps: Average Loss 0.281 | Accuracy: 89%
# [Step 10800] Past 100 steps: Average Loss 0.578 | Accuracy: 84%
# [Step 10900] Past 100 steps: Average Loss 0.541 | Accuracy: 82%
# [Step 11000] Past 100 steps: Average Loss 0.425 | Accuracy: 88%
# [Step 11100] Past 100 steps: Average Loss 0.393 | Accuracy: 90%
# [Step 11200] Past 100 steps: Average Loss 0.280 | Accuracy: 94%
# [Step 11300] Past 100 steps: Average Loss 0.293 | Accuracy: 91%
# [Step 11400] Past 100 steps: Average Loss 0.367 | Accuracy: 89%
# [Step 11500] Past 100 steps: Average Loss 0.387 | Accuracy: 86%
# [Step 11600] Past 100 steps: Average Loss 0.334 | Accuracy: 87%
# [Step 11700] Past 100 steps: Average Loss 0.305 | Accuracy: 90%
# [Step 11800] Past 100 steps: Average Loss 0.299 | Accuracy: 88%
# [Step 11900] Past 100 steps: Average Loss 0.363 | Accuracy: 91%
# [Step 12000] Past 100 steps: Average Loss 0.402 | Accuracy: 87%
# [Step 12100] Past 100 steps: Average Loss 0.217 | Accuracy: 94%
# [Step 12200] Past 100 steps: Average Loss 0.461 | Accuracy: 87%
# [Step 12300] Past 100 steps: Average Loss 0.307 | Accuracy: 89%
# [Step 12400] Past 100 steps: Average Loss 0.449 | Accuracy: 88%
# [Step 12500] Past 100 steps: Average Loss 0.501 | Accuracy: 83%
# [Step 12600] Past 100 steps: Average Loss 0.372 | Accuracy: 88%
# [Step 12700] Past 100 steps: Average Loss 0.369 | Accuracy: 85%
# [Step 12800] Past 100 steps: Average Loss 0.361 | Accuracy: 86%
# [Step 12900] Past 100 steps: Average Loss 0.332 | Accuracy: 90%
# [Step 13000] Past 100 steps: Average Loss 0.519 | Accuracy: 86%
# [Step 13100] Past 100 steps: Average Loss 0.583 | Accuracy: 87%
# [Step 13200] Past 100 steps: Average Loss 0.566 | Accuracy: 85%
# [Step 13300] Past 100 steps: Average Loss 0.317 | Accuracy: 90%
# [Step 13400] Past 100 steps: Average Loss 0.338 | Accuracy: 93%
# [Step 13500] Past 100 steps: Average Loss 0.561 | Accuracy: 83%
# [Step 13600] Past 100 steps: Average Loss 0.386 | Accuracy: 87%
# [Step 13700] Past 100 steps: Average Loss 0.311 | Accuracy: 88%
# [Step 13800] Past 100 steps: Average Loss 0.217 | Accuracy: 93%
# [Step 13900] Past 100 steps: Average Loss 0.232 | Accuracy: 90%
# [Step 14000] Past 100 steps: Average Loss 0.246 | Accuracy: 91%
# [Step 14100] Past 100 steps: Average Loss 0.408 | Accuracy: 91%
# [Step 14200] Past 100 steps: Average Loss 0.225 | Accuracy: 95%
# [Step 14300] Past 100 steps: Average Loss 0.384 | Accuracy: 84%
# [Step 14400] Past 100 steps: Average Loss 0.341 | Accuracy: 86%
# [Step 14500] Past 100 steps: Average Loss 0.339 | Accuracy: 90%
# [Step 14600] Past 100 steps: Average Loss 0.405 | Accuracy: 85%
# [Step 14700] Past 100 steps: Average Loss 0.351 | Accuracy: 86%
# [Step 14800] Past 100 steps: Average Loss 0.275 | Accuracy: 88%
# [Step 14900] Past 100 steps: Average Loss 0.176 | Accuracy: 94%
# [Step 15000] Past 100 steps: Average Loss 0.347 | Accuracy: 89%
# [Step 15100] Past 100 steps: Average Loss 0.279 | Accuracy: 90%
# [Step 15200] Past 100 steps: Average Loss 0.498 | Accuracy: 88%
# [Step 15300] Past 100 steps: Average Loss 0.219 | Accuracy: 93%
# [Step 15400] Past 100 steps: Average Loss 0.220 | Accuracy: 89%
# [Step 15500] Past 100 steps: Average Loss 0.251 | Accuracy: 92%
# [Step 15600] Past 100 steps: Average Loss 0.289 | Accuracy: 91%
# [Step 15700] Past 100 steps: Average Loss 0.253 | Accuracy: 90%
# [Step 15800] Past 100 steps: Average Loss 0.252 | Accuracy: 92%
# [Step 15900] Past 100 steps: Average Loss 0.357 | Accuracy: 89%
# [Step 16000] Past 100 steps: Average Loss 0.380 | Accuracy: 89%
# [Step 16100] Past 100 steps: Average Loss 0.336 | Accuracy: 90%
# [Step 16200] Past 100 steps: Average Loss 0.395 | Accuracy: 87%
# [Step 16300] Past 100 steps: Average Loss 0.301 | Accuracy: 94%
# [Step 16400] Past 100 steps: Average Loss 0.356 | Accuracy: 89%
# [Step 16500] Past 100 steps: Average Loss 0.314 | Accuracy: 93%
# [Step 16600] Past 100 steps: Average Loss 0.333 | Accuracy: 92%
# [Step 16700] Past 100 steps: Average Loss 0.340 | Accuracy: 88%
# [Step 16800] Past 100 steps: Average Loss 0.389 | Accuracy: 90%
# [Step 16900] Past 100 steps: Average Loss 0.369 | Accuracy: 92%
# [Step 17000] Past 100 steps: Average Loss 0.401 | Accuracy: 90%
# [Step 17100] Past 100 steps: Average Loss 0.346 | Accuracy: 92%
# [Step 17200] Past 100 steps: Average Loss 0.319 | Accuracy: 91%
# [Step 17300] Past 100 steps: Average Loss 0.255 | Accuracy: 93%
# [Step 17400] Past 100 steps: Average Loss 0.215 | Accuracy: 94%
# [Step 17500] Past 100 steps: Average Loss 0.342 | Accuracy: 91%
# [Step 17600] Past 100 steps: Average Loss 0.277 | Accuracy: 92%
# [Step 17700] Past 100 steps: Average Loss 0.222 | Accuracy: 94%
# [Step 17800] Past 100 steps: Average Loss 0.237 | Accuracy: 90%
# [Step 17900] Past 100 steps: Average Loss 0.360 | Accuracy: 90%
# [Step 18000] Past 100 steps: Average Loss 0.280 | Accuracy: 92%
# [Step 18100] Past 100 steps: Average Loss 0.221 | Accuracy: 92%
# [Step 18200] Past 100 steps: Average Loss 0.188 | Accuracy: 93%
# [Step 18300] Past 100 steps: Average Loss 0.146 | Accuracy: 95%
# [Step 18400] Past 100 steps: Average Loss 0.642 | Accuracy: 84%
# [Step 18500] Past 100 steps: Average Loss 0.317 | Accuracy: 90%
# [Step 18600] Past 100 steps: Average Loss 0.321 | Accuracy: 91%
# [Step 18700] Past 100 steps: Average Loss 0.194 | Accuracy: 94%
# [Step 18800] Past 100 steps: Average Loss 0.322 | Accuracy: 92%
# [Step 18900] Past 100 steps: Average Loss 0.453 | Accuracy: 85%
# [Step 19000] Past 100 steps: Average Loss 0.275 | Accuracy: 88%
# [Step 19100] Past 100 steps: Average Loss 0.305 | Accuracy: 91%
# [Step 19200] Past 100 steps: Average Loss 0.340 | Accuracy: 91%
# [Step 19300] Past 100 steps: Average Loss 0.214 | Accuracy: 96%
# [Step 19400] Past 100 steps: Average Loss 0.280 | Accuracy: 92%
# [Step 19500] Past 100 steps: Average Loss 0.279 | Accuracy: 93%
# [Step 19600] Past 100 steps: Average Loss 0.231 | Accuracy: 93%
# [Step 19700] Past 100 steps: Average Loss 0.282 | Accuracy: 89%
# [Step 19800] Past 100 steps: Average Loss 0.219 | Accuracy: 93%
# [Step 19900] Past 100 steps: Average Loss 0.310 | Accuracy: 93%
# [Step 20000] Past 100 steps: Average Loss 0.479 | Accuracy: 87%
# [Step 20100] Past 100 steps: Average Loss 0.284 | Accuracy: 93%
# [Step 20200] Past 100 steps: Average Loss 0.362 | Accuracy: 89%
# [Step 20300] Past 100 steps: Average Loss 0.201 | Accuracy: 94%
# [Step 20400] Past 100 steps: Average Loss 0.274 | Accuracy: 93%
# [Step 20500] Past 100 steps: Average Loss 0.171 | Accuracy: 95%
# [Step 20600] Past 100 steps: Average Loss 0.387 | Accuracy: 90%
# [Step 20700] Past 100 steps: Average Loss 0.213 | Accuracy: 95%
# [Step 20800] Past 100 steps: Average Loss 0.268 | Accuracy: 93%
# [Step 20900] Past 100 steps: Average Loss 0.314 | Accuracy: 89%
# [Step 21000] Past 100 steps: Average Loss 0.437 | Accuracy: 84%
# [Step 21100] Past 100 steps: Average Loss 0.240 | Accuracy: 93%
# [Step 21200] Past 100 steps: Average Loss 0.290 | Accuracy: 92%
# [Step 21300] Past 100 steps: Average Loss 0.306 | Accuracy: 89%
# [Step 21400] Past 100 steps: Average Loss 0.295 | Accuracy: 91%
# [Step 21500] Past 100 steps: Average Loss 0.487 | Accuracy: 86%
# [Step 21600] Past 100 steps: Average Loss 0.356 | Accuracy: 86%
# [Step 21700] Past 100 steps: Average Loss 0.393 | Accuracy: 90%
# [Step 21800] Past 100 steps: Average Loss 0.456 | Accuracy: 91%
# [Step 21900] Past 100 steps: Average Loss 0.409 | Accuracy: 91%
# [Step 22000] Past 100 steps: Average Loss 0.196 | Accuracy: 95%
# [Step 22100] Past 100 steps: Average Loss 0.373 | Accuracy: 91%
# [Step 22200] Past 100 steps: Average Loss 0.140 | Accuracy: 97%
# [Step 22300] Past 100 steps: Average Loss 0.239 | Accuracy: 92%
# [Step 22400] Past 100 steps: Average Loss 0.215 | Accuracy: 94%
# [Step 22500] Past 100 steps: Average Loss 0.421 | Accuracy: 87%
# [Step 22600] Past 100 steps: Average Loss 0.351 | Accuracy: 93%
# [Step 22700] Past 100 steps: Average Loss 0.297 | Accuracy: 92%
# [Step 22800] Past 100 steps: Average Loss 0.255 | Accuracy: 93%
# [Step 22900] Past 100 steps: Average Loss 0.202 | Accuracy: 95%
# [Step 23000] Past 100 steps: Average Loss 0.276 | Accuracy: 93%
# [Step 23100] Past 100 steps: Average Loss 0.387 | Accuracy: 91%
# [Step 23200] Past 100 steps: Average Loss 0.247 | Accuracy: 91%
# [Step 23300] Past 100 steps: Average Loss 0.416 | Accuracy: 88%
# [Step 23400] Past 100 steps: Average Loss 0.272 | Accuracy: 92%
# [Step 23500] Past 100 steps: Average Loss 0.219 | Accuracy: 91%
# [Step 23600] Past 100 steps: Average Loss 0.545 | Accuracy: 85%
# [Step 23700] Past 100 steps: Average Loss 0.391 | Accuracy: 90%
# [Step 23800] Past 100 steps: Average Loss 0.407 | Accuracy: 88%
# [Step 23900] Past 100 steps: Average Loss 0.218 | Accuracy: 93%
# [Step 24000] Past 100 steps: Average Loss 0.274 | Accuracy: 90%
# [Step 24100] Past 100 steps: Average Loss 0.272 | Accuracy: 88%
# [Step 24200] Past 100 steps: Average Loss 0.340 | Accuracy: 87%
# [Step 24300] Past 100 steps: Average Loss 0.312 | Accuracy: 89%
# [Step 24400] Past 100 steps: Average Loss 0.249 | Accuracy: 94%
# [Step 24500] Past 100 steps: Average Loss 0.291 | Accuracy: 90%
# [Step 24600] Past 100 steps: Average Loss 0.564 | Accuracy: 84%
# [Step 24700] Past 100 steps: Average Loss 0.152 | Accuracy: 95%
# [Step 24800] Past 100 steps: Average Loss 0.269 | Accuracy: 92%
# [Step 24900] Past 100 steps: Average Loss 0.329 | Accuracy: 93%
# [Step 25000] Past 100 steps: Average Loss 0.279 | Accuracy: 88%
# [Step 25100] Past 100 steps: Average Loss 0.482 | Accuracy: 86%
# [Step 25200] Past 100 steps: Average Loss 0.253 | Accuracy: 92%
# [Step 25300] Past 100 steps: Average Loss 0.360 | Accuracy: 92%
# [Step 25400] Past 100 steps: Average Loss 0.191 | Accuracy: 94%
# [Step 25500] Past 100 steps: Average Loss 0.156 | Accuracy: 94%
# [Step 25600] Past 100 steps: Average Loss 0.213 | Accuracy: 93%
# [Step 25700] Past 100 steps: Average Loss 0.280 | Accuracy: 91%
# [Step 25800] Past 100 steps: Average Loss 0.400 | Accuracy: 88%
# [Step 25900] Past 100 steps: Average Loss 0.382 | Accuracy: 86%
# [Step 26000] Past 100 steps: Average Loss 0.261 | Accuracy: 91%
# [Step 26100] Past 100 steps: Average Loss 0.323 | Accuracy: 93%
# [Step 26200] Past 100 steps: Average Loss 0.204 | Accuracy: 89%
# [Step 26300] Past 100 steps: Average Loss 0.235 | Accuracy: 93%
# [Step 26400] Past 100 steps: Average Loss 0.298 | Accuracy: 89%
# [Step 26500] Past 100 steps: Average Loss 0.324 | Accuracy: 90%
# [Step 26600] Past 100 steps: Average Loss 0.360 | Accuracy: 88%
# [Step 26700] Past 100 steps: Average Loss 0.426 | Accuracy: 90%
# [Step 26800] Past 100 steps: Average Loss 0.184 | Accuracy: 94%
# [Step 26900] Past 100 steps: Average Loss 0.185 | Accuracy: 95%
# [Step 27000] Past 100 steps: Average Loss 0.252 | Accuracy: 89%
# [Step 27100] Past 100 steps: Average Loss 0.234 | Accuracy: 92%
# [Step 27200] Past 100 steps: Average Loss 0.341 | Accuracy: 90%
# [Step 27300] Past 100 steps: Average Loss 0.202 | Accuracy: 97%
# [Step 27400] Past 100 steps: Average Loss 0.250 | Accuracy: 91%
# [Step 27500] Past 100 steps: Average Loss 0.306 | Accuracy: 90%
# [Step 27600] Past 100 steps: Average Loss 0.343 | Accuracy: 90%
# [Step 27700] Past 100 steps: Average Loss 0.179 | Accuracy: 94%
# [Step 27800] Past 100 steps: Average Loss 0.294 | Accuracy: 94%
# [Step 27900] Past 100 steps: Average Loss 0.323 | Accuracy: 89%
# [Step 28000] Past 100 steps: Average Loss 0.401 | Accuracy: 88%
# [Step 28100] Past 100 steps: Average Loss 0.288 | Accuracy: 90%
# [Step 28200] Past 100 steps: Average Loss 0.246 | Accuracy: 92%
# [Step 28300] Past 100 steps: Average Loss 0.224 | Accuracy: 95%
# [Step 28400] Past 100 steps: Average Loss 0.308 | Accuracy: 90%
# [Step 28500] Past 100 steps: Average Loss 0.294 | Accuracy: 89%
# [Step 28600] Past 100 steps: Average Loss 0.226 | Accuracy: 93%
# [Step 28700] Past 100 steps: Average Loss 0.425 | Accuracy: 87%
# [Step 28800] Past 100 steps: Average Loss 0.300 | Accuracy: 92%
# [Step 28900] Past 100 steps: Average Loss 0.251 | Accuracy: 89%
# [Step 29000] Past 100 steps: Average Loss 0.191 | Accuracy: 97%
# [Step 29100] Past 100 steps: Average Loss 0.320 | Accuracy: 90%
# [Step 29200] Past 100 steps: Average Loss 0.269 | Accuracy: 90%
# [Step 29300] Past 100 steps: Average Loss 0.310 | Accuracy: 91%
# [Step 29400] Past 100 steps: Average Loss 0.202 | Accuracy: 93%
# [Step 29500] Past 100 steps: Average Loss 0.255 | Accuracy: 91%
# [Step 29600] Past 100 steps: Average Loss 0.338 | Accuracy: 88%
# [Step 29700] Past 100 steps: Average Loss 0.283 | Accuracy: 92%
# [Step 29800] Past 100 steps: Average Loss 0.210 | Accuracy: 94%
# [Step 29900] Past 100 steps: Average Loss 0.335 | Accuracy: 91%
# [Step 30000] Past 100 steps: Average Loss 0.430 | Accuracy: 85%
# [Step 30100] Past 100 steps: Average Loss 0.204 | Accuracy: 95%
# [Step 30200] Past 100 steps: Average Loss 0.192 | Accuracy: 96%
# [Step 30300] Past 100 steps: Average Loss 0.155 | Accuracy: 96%
# [Step 30400] Past 100 steps: Average Loss 0.344 | Accuracy: 91%
# [Step 30500] Past 100 steps: Average Loss 0.195 | Accuracy: 94%
# [Step 30600] Past 100 steps: Average Loss 0.203 | Accuracy: 93%
# [Step 30700] Past 100 steps: Average Loss 0.229 | Accuracy: 91%
# [Step 30800] Past 100 steps: Average Loss 0.415 | Accuracy: 86%
# [Step 30900] Past 100 steps: Average Loss 0.236 | Accuracy: 94%
# [Step 31000] Past 100 steps: Average Loss 0.247 | Accuracy: 89%
# [Step 31100] Past 100 steps: Average Loss 0.352 | Accuracy: 93%
# [Step 31200] Past 100 steps: Average Loss 0.143 | Accuracy: 96%
# [Step 31300] Past 100 steps: Average Loss 0.225 | Accuracy: 92%
# [Step 31400] Past 100 steps: Average Loss 0.300 | Accuracy: 93%
# [Step 31500] Past 100 steps: Average Loss 0.240 | Accuracy: 92%
# [Step 31600] Past 100 steps: Average Loss 0.252 | Accuracy: 94%
# [Step 31700] Past 100 steps: Average Loss 0.326 | Accuracy: 87%
# [Step 31800] Past 100 steps: Average Loss 0.244 | Accuracy: 93%
# [Step 31900] Past 100 steps: Average Loss 0.162 | Accuracy: 95%
# [Step 32000] Past 100 steps: Average Loss 0.189 | Accuracy: 94%
# [Step 32100] Past 100 steps: Average Loss 0.296 | Accuracy: 88%
# [Step 32200] Past 100 steps: Average Loss 0.179 | Accuracy: 94%
# [Step 32300] Past 100 steps: Average Loss 0.252 | Accuracy: 92%
# [Step 32400] Past 100 steps: Average Loss 0.163 | Accuracy: 95%
# [Step 32500] Past 100 steps: Average Loss 0.205 | Accuracy: 92%
# [Step 32600] Past 100 steps: Average Loss 0.308 | Accuracy: 93%
# [Step 32700] Past 100 steps: Average Loss 0.279 | Accuracy: 91%
# [Step 32800] Past 100 steps: Average Loss 0.319 | Accuracy: 89%
# [Step 32900] Past 100 steps: Average Loss 0.112 | Accuracy: 97%
# [Step 33000] Past 100 steps: Average Loss 0.196 | Accuracy: 93%
# [Step 33100] Past 100 steps: Average Loss 0.171 | Accuracy: 95%
# [Step 33200] Past 100 steps: Average Loss 0.229 | Accuracy: 94%
# [Step 33300] Past 100 steps: Average Loss 0.239 | Accuracy: 90%
# [Step 33400] Past 100 steps: Average Loss 0.346 | Accuracy: 91%
# [Step 33500] Past 100 steps: Average Loss 0.238 | Accuracy: 92%
# [Step 33600] Past 100 steps: Average Loss 0.431 | Accuracy: 88%
# [Step 33700] Past 100 steps: Average Loss 0.161 | Accuracy: 95%
# [Step 33800] Past 100 steps: Average Loss 0.253 | Accuracy: 93%
# [Step 33900] Past 100 steps: Average Loss 0.197 | Accuracy: 94%
# [Step 34000] Past 100 steps: Average Loss 0.167 | Accuracy: 94%
# [Step 34100] Past 100 steps: Average Loss 0.296 | Accuracy: 93%
# [Step 34200] Past 100 steps: Average Loss 0.320 | Accuracy: 92%
# [Step 34300] Past 100 steps: Average Loss 0.240 | Accuracy: 92%
# [Step 34400] Past 100 steps: Average Loss 0.146 | Accuracy: 94%
# [Step 34500] Past 100 steps: Average Loss 0.205 | Accuracy: 93%
# [Step 34600] Past 100 steps: Average Loss 0.184 | Accuracy: 93%
# [Step 34700] Past 100 steps: Average Loss 0.247 | Accuracy: 93%
# [Step 34800] Past 100 steps: Average Loss 0.346 | Accuracy: 94%
# [Step 34900] Past 100 steps: Average Loss 0.198 | Accuracy: 95%
# [Step 35000] Past 100 steps: Average Loss 0.259 | Accuracy: 91%
# [Step 35100] Past 100 steps: Average Loss 0.187 | Accuracy: 93%
# [Step 35200] Past 100 steps: Average Loss 0.238 | Accuracy: 92%
# [Step 35300] Past 100 steps: Average Loss 0.175 | Accuracy: 96%
# [Step 35400] Past 100 steps: Average Loss 0.394 | Accuracy: 90%
# [Step 35500] Past 100 steps: Average Loss 0.159 | Accuracy: 96%
# [Step 35600] Past 100 steps: Average Loss 0.261 | Accuracy: 94%
# [Step 35700] Past 100 steps: Average Loss 0.265 | Accuracy: 92%
# [Step 35800] Past 100 steps: Average Loss 0.317 | Accuracy: 92%
# [Step 35900] Past 100 steps: Average Loss 0.235 | Accuracy: 91%
# [Step 36000] Past 100 steps: Average Loss 0.208 | Accuracy: 90%
# [Step 36100] Past 100 steps: Average Loss 0.181 | Accuracy: 94%
# [Step 36200] Past 100 steps: Average Loss 0.137 | Accuracy: 94%
# [Step 36300] Past 100 steps: Average Loss 0.258 | Accuracy: 94%
# [Step 36400] Past 100 steps: Average Loss 0.139 | Accuracy: 95%
# [Step 36500] Past 100 steps: Average Loss 0.182 | Accuracy: 95%
# [Step 36600] Past 100 steps: Average Loss 0.210 | Accuracy: 95%
# [Step 36700] Past 100 steps: Average Loss 0.236 | Accuracy: 95%
# [Step 36800] Past 100 steps: Average Loss 0.295 | Accuracy: 95%
# [Step 36900] Past 100 steps: Average Loss 0.306 | Accuracy: 91%
# [Step 37000] Past 100 steps: Average Loss 0.266 | Accuracy: 92%
# [Step 37100] Past 100 steps: Average Loss 0.325 | Accuracy: 91%
# [Step 37200] Past 100 steps: Average Loss 0.162 | Accuracy: 96%
# [Step 37300] Past 100 steps: Average Loss 0.370 | Accuracy: 93%
# [Step 37400] Past 100 steps: Average Loss 0.108 | Accuracy: 96%
# [Step 37500] Past 100 steps: Average Loss 0.163 | Accuracy: 95%
# [Step 37600] Past 100 steps: Average Loss 0.217 | Accuracy: 96%
# [Step 37700] Past 100 steps: Average Loss 0.207 | Accuracy: 95%
# [Step 37800] Past 100 steps: Average Loss 0.233 | Accuracy: 96%
# [Step 37900] Past 100 steps: Average Loss 0.268 | Accuracy: 89%
# [Step 38000] Past 100 steps: Average Loss 0.195 | Accuracy: 90%
# [Step 38100] Past 100 steps: Average Loss 0.147 | Accuracy: 95%
# [Step 38200] Past 100 steps: Average Loss 0.281 | Accuracy: 93%
# [Step 38300] Past 100 steps: Average Loss 0.159 | Accuracy: 92%
# [Step 38400] Past 100 steps: Average Loss 0.286 | Accuracy: 89%
# [Step 38500] Past 100 steps: Average Loss 0.087 | Accuracy: 98%
# [Step 38600] Past 100 steps: Average Loss 0.141 | Accuracy: 93%
# [Step 38700] Past 100 steps: Average Loss 0.316 | Accuracy: 93%
# [Step 38800] Past 100 steps: Average Loss 0.105 | Accuracy: 96%
# [Step 38900] Past 100 steps: Average Loss 0.398 | Accuracy: 87%
# [Step 39000] Past 100 steps: Average Loss 0.323 | Accuracy: 90%
# [Step 39100] Past 100 steps: Average Loss 0.139 | Accuracy: 98%
# [Step 39200] Past 100 steps: Average Loss 0.434 | Accuracy: 88%
# [Step 39300] Past 100 steps: Average Loss 0.181 | Accuracy: 93%
# [Step 39400] Past 100 steps: Average Loss 0.196 | Accuracy: 96%
# [Step 39500] Past 100 steps: Average Loss 0.103 | Accuracy: 96%
# [Step 39600] Past 100 steps: Average Loss 0.253 | Accuracy: 94%
# [Step 39700] Past 100 steps: Average Loss 0.175 | Accuracy: 95%
# [Step 39800] Past 100 steps: Average Loss 0.263 | Accuracy: 93%
# [Step 39900] Past 100 steps: Average Loss 0.356 | Accuracy: 89%
# [Step 40000] Past 100 steps: Average Loss 0.149 | Accuracy: 97%
# [Step 40100] Past 100 steps: Average Loss 0.438 | Accuracy: 86%
# [Step 40200] Past 100 steps: Average Loss 0.180 | Accuracy: 92%
# [Step 40300] Past 100 steps: Average Loss 0.182 | Accuracy: 94%
# [Step 40400] Past 100 steps: Average Loss 0.568 | Accuracy: 89%
# [Step 40500] Past 100 steps: Average Loss 0.224 | Accuracy: 95%
# [Step 40600] Past 100 steps: Average Loss 0.338 | Accuracy: 90%
# [Step 40700] Past 100 steps: Average Loss 0.182 | Accuracy: 96%
# [Step 40800] Past 100 steps: Average Loss 0.223 | Accuracy: 95%
# [Step 40900] Past 100 steps: Average Loss 0.235 | Accuracy: 92%
# [Step 41000] Past 100 steps: Average Loss 0.291 | Accuracy: 93%
# [Step 41100] Past 100 steps: Average Loss 0.186 | Accuracy: 95%
# [Step 41200] Past 100 steps: Average Loss 0.256 | Accuracy: 91%
# [Step 41300] Past 100 steps: Average Loss 0.493 | Accuracy: 84%
# [Step 41400] Past 100 steps: Average Loss 0.349 | Accuracy: 90%
# [Step 41500] Past 100 steps: Average Loss 0.259 | Accuracy: 92%
# [Step 41600] Past 100 steps: Average Loss 0.201 | Accuracy: 92%
# [Step 41700] Past 100 steps: Average Loss 0.187 | Accuracy: 94%
# [Step 41800] Past 100 steps: Average Loss 0.292 | Accuracy: 91%
# [Step 41900] Past 100 steps: Average Loss 0.287 | Accuracy: 92%
# [Step 42000] Past 100 steps: Average Loss 0.212 | Accuracy: 92%
# ----EPOCH 2 ---
# [Step 100] Past 100 steps: Average Loss 0.280 | Accuracy: 88%
# [Step 200] Past 100 steps: Average Loss 0.341 | Accuracy: 85%
# [Step 300] Past 100 steps: Average Loss 0.184 | Accuracy: 93%
# [Step 400] Past 100 steps: Average Loss 0.117 | Accuracy: 97%
# [Step 500] Past 100 steps: Average Loss 0.327 | Accuracy: 92%
# [Step 600] Past 100 steps: Average Loss 0.248 | Accuracy: 92%
# [Step 700] Past 100 steps: Average Loss 0.404 | Accuracy: 91%
# [Step 800] Past 100 steps: Average Loss 0.126 | Accuracy: 97%
# [Step 900] Past 100 steps: Average Loss 0.310 | Accuracy: 93%
# [Step 1000] Past 100 steps: Average Loss 0.082 | Accuracy: 97%
# [Step 1100] Past 100 steps: Average Loss 0.224 | Accuracy: 92%
# [Step 1200] Past 100 steps: Average Loss 0.260 | Accuracy: 90%
# [Step 1300] Past 100 steps: Average Loss 0.110 | Accuracy: 97%
# [Step 1400] Past 100 steps: Average Loss 0.188 | Accuracy: 95%
# [Step 1500] Past 100 steps: Average Loss 0.137 | Accuracy: 96%
# [Step 1600] Past 100 steps: Average Loss 0.127 | Accuracy: 97%
# [Step 1700] Past 100 steps: Average Loss 0.229 | Accuracy: 95%
# [Step 1800] Past 100 steps: Average Loss 0.371 | Accuracy: 93%
# [Step 1900] Past 100 steps: Average Loss 0.177 | Accuracy: 95%
# [Step 2000] Past 100 steps: Average Loss 0.331 | Accuracy: 90%
# [Step 2100] Past 100 steps: Average Loss 0.187 | Accuracy: 93%
# [Step 2200] Past 100 steps: Average Loss 0.302 | Accuracy: 92%
# [Step 2300] Past 100 steps: Average Loss 0.253 | Accuracy: 94%
# [Step 2400] Past 100 steps: Average Loss 0.454 | Accuracy: 88%
# [Step 2500] Past 100 steps: Average Loss 0.167 | Accuracy: 95%
# [Step 2600] Past 100 steps: Average Loss 0.250 | Accuracy: 94%
# [Step 2700] Past 100 steps: Average Loss 0.149 | Accuracy: 95%
# [Step 2800] Past 100 steps: Average Loss 0.309 | Accuracy: 90%
# [Step 2900] Past 100 steps: Average Loss 0.113 | Accuracy: 94%
# [Step 3000] Past 100 steps: Average Loss 0.354 | Accuracy: 88%
# [Step 3100] Past 100 steps: Average Loss 0.226 | Accuracy: 92%
# [Step 3200] Past 100 steps: Average Loss 0.132 | Accuracy: 96%
# [Step 3300] Past 100 steps: Average Loss 0.170 | Accuracy: 94%
# [Step 3400] Past 100 steps: Average Loss 0.275 | Accuracy: 93%
# [Step 3500] Past 100 steps: Average Loss 0.085 | Accuracy: 97%
# [Step 3600] Past 100 steps: Average Loss 0.353 | Accuracy: 91%
# [Step 3700] Past 100 steps: Average Loss 0.303 | Accuracy: 90%
# [Step 3800] Past 100 steps: Average Loss 0.384 | Accuracy: 88%
# [Step 3900] Past 100 steps: Average Loss 0.243 | Accuracy: 94%
# [Step 4000] Past 100 steps: Average Loss 0.123 | Accuracy: 98%
# [Step 4100] Past 100 steps: Average Loss 0.177 | Accuracy: 96%
# [Step 4200] Past 100 steps: Average Loss 0.185 | Accuracy: 97%
# [Step 4300] Past 100 steps: Average Loss 0.171 | Accuracy: 96%
# [Step 4400] Past 100 steps: Average Loss 0.236 | Accuracy: 93%
# [Step 4500] Past 100 steps: Average Loss 0.256 | Accuracy: 89%
# [Step 4600] Past 100 steps: Average Loss 0.121 | Accuracy: 95%
# [Step 4700] Past 100 steps: Average Loss 0.339 | Accuracy: 90%
# [Step 4800] Past 100 steps: Average Loss 0.177 | Accuracy: 94%
# [Step 4900] Past 100 steps: Average Loss 0.269 | Accuracy: 90%
# [Step 5000] Past 100 steps: Average Loss 0.239 | Accuracy: 90%
# [Step 5100] Past 100 steps: Average Loss 0.288 | Accuracy: 95%
# [Step 5200] Past 100 steps: Average Loss 0.212 | Accuracy: 96%
# [Step 5300] Past 100 steps: Average Loss 0.129 | Accuracy: 95%
# [Step 5400] Past 100 steps: Average Loss 0.337 | Accuracy: 88%
# [Step 5500] Past 100 steps: Average Loss 0.188 | Accuracy: 94%
# [Step 5600] Past 100 steps: Average Loss 0.137 | Accuracy: 95%
# [Step 5700] Past 100 steps: Average Loss 0.238 | Accuracy: 93%
# [Step 5800] Past 100 steps: Average Loss 0.196 | Accuracy: 93%
# [Step 5900] Past 100 steps: Average Loss 0.322 | Accuracy: 89%
# [Step 6000] Past 100 steps: Average Loss 0.369 | Accuracy: 91%
# [Step 6100] Past 100 steps: Average Loss 0.166 | Accuracy: 92%
# [Step 6200] Past 100 steps: Average Loss 0.398 | Accuracy: 91%
# [Step 6300] Past 100 steps: Average Loss 0.305 | Accuracy: 88%
# [Step 6400] Past 100 steps: Average Loss 0.158 | Accuracy: 95%
# [Step 6500] Past 100 steps: Average Loss 0.130 | Accuracy: 97%
# [Step 6600] Past 100 steps: Average Loss 0.318 | Accuracy: 95%
# [Step 6700] Past 100 steps: Average Loss 0.310 | Accuracy: 89%
# [Step 6800] Past 100 steps: Average Loss 0.211 | Accuracy: 94%
# [Step 6900] Past 100 steps: Average Loss 0.301 | Accuracy: 91%
# [Step 7000] Past 100 steps: Average Loss 0.213 | Accuracy: 92%
# [Step 7100] Past 100 steps: Average Loss 0.201 | Accuracy: 93%
# [Step 7200] Past 100 steps: Average Loss 0.354 | Accuracy: 90%
# [Step 7300] Past 100 steps: Average Loss 0.249 | Accuracy: 91%
# [Step 7400] Past 100 steps: Average Loss 0.202 | Accuracy: 93%
# [Step 7500] Past 100 steps: Average Loss 0.260 | Accuracy: 91%
# [Step 7600] Past 100 steps: Average Loss 0.441 | Accuracy: 88%
# [Step 7700] Past 100 steps: Average Loss 0.419 | Accuracy: 90%
# [Step 7800] Past 100 steps: Average Loss 0.289 | Accuracy: 93%
# [Step 7900] Past 100 steps: Average Loss 0.169 | Accuracy: 93%
# [Step 8000] Past 100 steps: Average Loss 0.260 | Accuracy: 95%
# [Step 8100] Past 100 steps: Average Loss 0.198 | Accuracy: 96%
# [Step 8200] Past 100 steps: Average Loss 0.277 | Accuracy: 90%
# [Step 8300] Past 100 steps: Average Loss 0.197 | Accuracy: 92%
# [Step 8400] Past 100 steps: Average Loss 0.242 | Accuracy: 92%
# [Step 8500] Past 100 steps: Average Loss 0.230 | Accuracy: 91%
# [Step 8600] Past 100 steps: Average Loss 0.039 | Accuracy: 100%
# [Step 8700] Past 100 steps: Average Loss 0.408 | Accuracy: 90%
# [Step 8800] Past 100 steps: Average Loss 0.257 | Accuracy: 93%
# [Step 8900] Past 100 steps: Average Loss 0.277 | Accuracy: 90%
# [Step 9000] Past 100 steps: Average Loss 0.173 | Accuracy: 93%
# [Step 9100] Past 100 steps: Average Loss 0.146 | Accuracy: 94%
# [Step 9200] Past 100 steps: Average Loss 0.169 | Accuracy: 94%
# [Step 9300] Past 100 steps: Average Loss 0.080 | Accuracy: 98%
# [Step 9400] Past 100 steps: Average Loss 0.224 | Accuracy: 93%
# [Step 9500] Past 100 steps: Average Loss 0.291 | Accuracy: 92%
# [Step 9600] Past 100 steps: Average Loss 0.322 | Accuracy: 89%
# [Step 9700] Past 100 steps: Average Loss 0.097 | Accuracy: 96%
# [Step 9800] Past 100 steps: Average Loss 0.378 | Accuracy: 91%
# [Step 9900] Past 100 steps: Average Loss 0.129 | Accuracy: 94%
# [Step 10000] Past 100 steps: Average Loss 0.372 | Accuracy: 89%
# [Step 10100] Past 100 steps: Average Loss 0.076 | Accuracy: 97%
# [Step 10200] Past 100 steps: Average Loss 0.123 | Accuracy: 98%
# [Step 10300] Past 100 steps: Average Loss 0.247 | Accuracy: 93%
# [Step 10400] Past 100 steps: Average Loss 0.233 | Accuracy: 94%
# [Step 10500] Past 100 steps: Average Loss 0.136 | Accuracy: 97%
# [Step 10600] Past 100 steps: Average Loss 0.286 | Accuracy: 91%
# [Step 10700] Past 100 steps: Average Loss 0.071 | Accuracy: 98%
# [Step 10800] Past 100 steps: Average Loss 0.332 | Accuracy: 91%
# [Step 10900] Past 100 steps: Average Loss 0.397 | Accuracy: 89%
# [Step 11000] Past 100 steps: Average Loss 0.186 | Accuracy: 95%
# [Step 11100] Past 100 steps: Average Loss 0.342 | Accuracy: 90%
# [Step 11200] Past 100 steps: Average Loss 0.174 | Accuracy: 96%
# [Step 11300] Past 100 steps: Average Loss 0.094 | Accuracy: 99%
# [Step 11400] Past 100 steps: Average Loss 0.290 | Accuracy: 93%
# [Step 11500] Past 100 steps: Average Loss 0.207 | Accuracy: 91%
# [Step 11600] Past 100 steps: Average Loss 0.273 | Accuracy: 92%
# [Step 11700] Past 100 steps: Average Loss 0.240 | Accuracy: 91%
# [Step 11800] Past 100 steps: Average Loss 0.200 | Accuracy: 93%
# [Step 11900] Past 100 steps: Average Loss 0.299 | Accuracy: 90%
# [Step 12000] Past 100 steps: Average Loss 0.249 | Accuracy: 91%
# [Step 12100] Past 100 steps: Average Loss 0.058 | Accuracy: 99%
# [Step 12200] Past 100 steps: Average Loss 0.329 | Accuracy: 90%
# [Step 12300] Past 100 steps: Average Loss 0.094 | Accuracy: 97%
# [Step 12400] Past 100 steps: Average Loss 0.361 | Accuracy: 90%
# [Step 12500] Past 100 steps: Average Loss 0.312 | Accuracy: 91%
# [Step 12600] Past 100 steps: Average Loss 0.276 | Accuracy: 93%
# [Step 12700] Past 100 steps: Average Loss 0.170 | Accuracy: 93%
# [Step 12800] Past 100 steps: Average Loss 0.233 | Accuracy: 94%
# [Step 12900] Past 100 steps: Average Loss 0.254 | Accuracy: 95%
# [Step 13000] Past 100 steps: Average Loss 0.403 | Accuracy: 88%
# [Step 13100] Past 100 steps: Average Loss 0.497 | Accuracy: 90%
# [Step 13200] Past 100 steps: Average Loss 0.571 | Accuracy: 85%
# [Step 13300] Past 100 steps: Average Loss 0.174 | Accuracy: 93%
# [Step 13400] Past 100 steps: Average Loss 0.189 | Accuracy: 96%
# [Step 13500] Past 100 steps: Average Loss 0.581 | Accuracy: 87%
# [Step 13600] Past 100 steps: Average Loss 0.236 | Accuracy: 92%
# [Step 13700] Past 100 steps: Average Loss 0.157 | Accuracy: 93%
# [Step 13800] Past 100 steps: Average Loss 0.118 | Accuracy: 95%
# [Step 13900] Past 100 steps: Average Loss 0.176 | Accuracy: 94%
# [Step 14000] Past 100 steps: Average Loss 0.105 | Accuracy: 97%
# [Step 14100] Past 100 steps: Average Loss 0.245 | Accuracy: 95%
# [Step 14200] Past 100 steps: Average Loss 0.191 | Accuracy: 95%
# [Step 14300] Past 100 steps: Average Loss 0.170 | Accuracy: 93%
# [Step 14400] Past 100 steps: Average Loss 0.206 | Accuracy: 93%
# [Step 14500] Past 100 steps: Average Loss 0.299 | Accuracy: 90%
# [Step 14600] Past 100 steps: Average Loss 0.261 | Accuracy: 93%
# [Step 14700] Past 100 steps: Average Loss 0.196 | Accuracy: 96%
# [Step 14800] Past 100 steps: Average Loss 0.132 | Accuracy: 96%
# [Step 14900] Past 100 steps: Average Loss 0.045 | Accuracy: 99%
# [Step 15000] Past 100 steps: Average Loss 0.228 | Accuracy: 94%
# [Step 15100] Past 100 steps: Average Loss 0.219 | Accuracy: 94%
# [Step 15200] Past 100 steps: Average Loss 0.381 | Accuracy: 93%
# [Step 15300] Past 100 steps: Average Loss 0.147 | Accuracy: 94%
# [Step 15400] Past 100 steps: Average Loss 0.085 | Accuracy: 97%
# [Step 15500] Past 100 steps: Average Loss 0.105 | Accuracy: 94%
# [Step 15600] Past 100 steps: Average Loss 0.218 | Accuracy: 89%
# [Step 15700] Past 100 steps: Average Loss 0.183 | Accuracy: 94%
# [Step 15800] Past 100 steps: Average Loss 0.120 | Accuracy: 97%
# [Step 15900] Past 100 steps: Average Loss 0.176 | Accuracy: 94%
# [Step 16000] Past 100 steps: Average Loss 0.239 | Accuracy: 92%
# [Step 16100] Past 100 steps: Average Loss 0.284 | Accuracy: 92%
# [Step 16200] Past 100 steps: Average Loss 0.247 | Accuracy: 94%
# [Step 16300] Past 100 steps: Average Loss 0.230 | Accuracy: 94%
# [Step 16400] Past 100 steps: Average Loss 0.249 | Accuracy: 96%
# [Step 16500] Past 100 steps: Average Loss 0.189 | Accuracy: 94%
# [Step 16600] Past 100 steps: Average Loss 0.208 | Accuracy: 94%
# [Step 16700] Past 100 steps: Average Loss 0.221 | Accuracy: 92%
# [Step 16800] Past 100 steps: Average Loss 0.192 | Accuracy: 93%
# [Step 16900] Past 100 steps: Average Loss 0.320 | Accuracy: 93%
# [Step 17000] Past 100 steps: Average Loss 0.244 | Accuracy: 95%
# [Step 17100] Past 100 steps: Average Loss 0.276 | Accuracy: 92%
# [Step 17200] Past 100 steps: Average Loss 0.174 | Accuracy: 97%
# [Step 17300] Past 100 steps: Average Loss 0.147 | Accuracy: 95%
# [Step 17400] Past 100 steps: Average Loss 0.210 | Accuracy: 93%
# [Step 17500] Past 100 steps: Average Loss 0.263 | Accuracy: 94%
# [Step 17600] Past 100 steps: Average Loss 0.256 | Accuracy: 93%
# [Step 17700] Past 100 steps: Average Loss 0.125 | Accuracy: 96%
# [Step 17800] Past 100 steps: Average Loss 0.261 | Accuracy: 91%
# [Step 17900] Past 100 steps: Average Loss 0.371 | Accuracy: 90%
# [Step 18000] Past 100 steps: Average Loss 0.162 | Accuracy: 96%
# [Step 18100] Past 100 steps: Average Loss 0.145 | Accuracy: 95%
# [Step 18200] Past 100 steps: Average Loss 0.116 | Accuracy: 94%
# [Step 18300] Past 100 steps: Average Loss 0.065 | Accuracy: 98%
# [Step 18400] Past 100 steps: Average Loss 0.544 | Accuracy: 89%
# [Step 18500] Past 100 steps: Average Loss 0.327 | Accuracy: 89%
# [Step 18600] Past 100 steps: Average Loss 0.193 | Accuracy: 93%
# [Step 18700] Past 100 steps: Average Loss 0.109 | Accuracy: 98%
# [Step 18800] Past 100 steps: Average Loss 0.300 | Accuracy: 88%
# [Step 18900] Past 100 steps: Average Loss 0.389 | Accuracy: 88%
# [Step 19000] Past 100 steps: Average Loss 0.139 | Accuracy: 96%
# [Step 19100] Past 100 steps: Average Loss 0.287 | Accuracy: 92%
# [Step 19200] Past 100 steps: Average Loss 0.202 | Accuracy: 97%
# [Step 19300] Past 100 steps: Average Loss 0.279 | Accuracy: 94%
# [Step 19400] Past 100 steps: Average Loss 0.231 | Accuracy: 93%
# [Step 19500] Past 100 steps: Average Loss 0.205 | Accuracy: 93%
# [Step 19600] Past 100 steps: Average Loss 0.111 | Accuracy: 97%
# [Step 19700] Past 100 steps: Average Loss 0.226 | Accuracy: 95%
# [Step 19800] Past 100 steps: Average Loss 0.118 | Accuracy: 96%
# [Step 19900] Past 100 steps: Average Loss 0.385 | Accuracy: 93%
# [Step 20000] Past 100 steps: Average Loss 0.381 | Accuracy: 90%
# [Step 20100] Past 100 steps: Average Loss 0.212 | Accuracy: 94%
# [Step 20200] Past 100 steps: Average Loss 0.362 | Accuracy: 86%
# [Step 20300] Past 100 steps: Average Loss 0.075 | Accuracy: 97%
# [Step 20400] Past 100 steps: Average Loss 0.229 | Accuracy: 95%
# [Step 20500] Past 100 steps: Average Loss 0.096 | Accuracy: 96%
# [Step 20600] Past 100 steps: Average Loss 0.383 | Accuracy: 94%
# [Step 20700] Past 100 steps: Average Loss 0.149 | Accuracy: 96%
# [Step 20800] Past 100 steps: Average Loss 0.153 | Accuracy: 94%
# [Step 20900] Past 100 steps: Average Loss 0.204 | Accuracy: 93%
# [Step 21000] Past 100 steps: Average Loss 0.494 | Accuracy: 87%
# [Step 21100] Past 100 steps: Average Loss 0.144 | Accuracy: 94%
# [Step 21200] Past 100 steps: Average Loss 0.171 | Accuracy: 95%
# [Step 21300] Past 100 steps: Average Loss 0.210 | Accuracy: 95%
# [Step 21400] Past 100 steps: Average Loss 0.206 | Accuracy: 95%
# [Step 21500] Past 100 steps: Average Loss 0.465 | Accuracy: 90%
# [Step 21600] Past 100 steps: Average Loss 0.279 | Accuracy: 93%
# [Step 21700] Past 100 steps: Average Loss 0.450 | Accuracy: 92%
# [Step 21800] Past 100 steps: Average Loss 0.324 | Accuracy: 92%
# [Step 21900] Past 100 steps: Average Loss 0.359 | Accuracy: 91%
# [Step 22000] Past 100 steps: Average Loss 0.174 | Accuracy: 95%
# [Step 22100] Past 100 steps: Average Loss 0.311 | Accuracy: 90%
# [Step 22200] Past 100 steps: Average Loss 0.110 | Accuracy: 97%
# [Step 22300] Past 100 steps: Average Loss 0.226 | Accuracy: 92%
# [Step 22400] Past 100 steps: Average Loss 0.209 | Accuracy: 96%
# [Step 22500] Past 100 steps: Average Loss 0.382 | Accuracy: 88%
# [Step 22600] Past 100 steps: Average Loss 0.262 | Accuracy: 93%
# [Step 22700] Past 100 steps: Average Loss 0.255 | Accuracy: 96%
# [Step 22800] Past 100 steps: Average Loss 0.173 | Accuracy: 93%
# [Step 22900] Past 100 steps: Average Loss 0.135 | Accuracy: 98%
# [Step 23000] Past 100 steps: Average Loss 0.294 | Accuracy: 94%
# [Step 23100] Past 100 steps: Average Loss 0.376 | Accuracy: 91%
# [Step 23200] Past 100 steps: Average Loss 0.173 | Accuracy: 94%
# [Step 23300] Past 100 steps: Average Loss 0.354 | Accuracy: 89%
# [Step 23400] Past 100 steps: Average Loss 0.220 | Accuracy: 92%
# [Step 23500] Past 100 steps: Average Loss 0.160 | Accuracy: 95%
# [Step 23600] Past 100 steps: Average Loss 0.505 | Accuracy: 92%
# [Step 23700] Past 100 steps: Average Loss 0.358 | Accuracy: 91%
# [Step 23800] Past 100 steps: Average Loss 0.381 | Accuracy: 89%
# [Step 23900] Past 100 steps: Average Loss 0.080 | Accuracy: 97%
# [Step 24000] Past 100 steps: Average Loss 0.214 | Accuracy: 90%
# [Step 24100] Past 100 steps: Average Loss 0.201 | Accuracy: 91%
# [Step 24200] Past 100 steps: Average Loss 0.279 | Accuracy: 93%
# [Step 24300] Past 100 steps: Average Loss 0.354 | Accuracy: 90%
# [Step 24400] Past 100 steps: Average Loss 0.160 | Accuracy: 96%
# [Step 24500] Past 100 steps: Average Loss 0.290 | Accuracy: 92%
# [Step 24600] Past 100 steps: Average Loss 0.629 | Accuracy: 85%
# [Step 24700] Past 100 steps: Average Loss 0.087 | Accuracy: 96%
# [Step 24800] Past 100 steps: Average Loss 0.169 | Accuracy: 94%
# [Step 24900] Past 100 steps: Average Loss 0.315 | Accuracy: 91%
# [Step 25000] Past 100 steps: Average Loss 0.271 | Accuracy: 91%
# [Step 25100] Past 100 steps: Average Loss 0.455 | Accuracy: 91%
# [Step 25200] Past 100 steps: Average Loss 0.303 | Accuracy: 87%
# [Step 25300] Past 100 steps: Average Loss 0.451 | Accuracy: 89%
# [Step 25400] Past 100 steps: Average Loss 0.091 | Accuracy: 97%
# [Step 25500] Past 100 steps: Average Loss 0.063 | Accuracy: 98%
# [Step 25600] Past 100 steps: Average Loss 0.102 | Accuracy: 95%
# [Step 25700] Past 100 steps: Average Loss 0.217 | Accuracy: 95%
# [Step 25800] Past 100 steps: Average Loss 0.415 | Accuracy: 89%
# [Step 25900] Past 100 steps: Average Loss 0.329 | Accuracy: 89%
# [Step 26000] Past 100 steps: Average Loss 0.263 | Accuracy: 94%
# [Step 26100] Past 100 steps: Average Loss 0.267 | Accuracy: 95%
# [Step 26200] Past 100 steps: Average Loss 0.204 | Accuracy: 92%
# [Step 26300] Past 100 steps: Average Loss 0.204 | Accuracy: 92%
# [Step 26400] Past 100 steps: Average Loss 0.233 | Accuracy: 92%
# [Step 26500] Past 100 steps: Average Loss 0.322 | Accuracy: 88%
# [Step 26600] Past 100 steps: Average Loss 0.283 | Accuracy: 92%
# [Step 26700] Past 100 steps: Average Loss 0.387 | Accuracy: 91%
# [Step 26800] Past 100 steps: Average Loss 0.079 | Accuracy: 98%
# [Step 26900] Past 100 steps: Average Loss 0.120 | Accuracy: 96%
# [Step 27000] Past 100 steps: Average Loss 0.143 | Accuracy: 95%
# [Step 27100] Past 100 steps: Average Loss 0.255 | Accuracy: 94%
# [Step 27200] Past 100 steps: Average Loss 0.267 | Accuracy: 93%
# [Step 27300] Past 100 steps: Average Loss 0.202 | Accuracy: 93%
# [Step 27400] Past 100 steps: Average Loss 0.119 | Accuracy: 97%
# [Step 27500] Past 100 steps: Average Loss 0.268 | Accuracy: 93%
# [Step 27600] Past 100 steps: Average Loss 0.250 | Accuracy: 91%
# [Step 27700] Past 100 steps: Average Loss 0.202 | Accuracy: 94%
# [Step 27800] Past 100 steps: Average Loss 0.216 | Accuracy: 96%
# [Step 27900] Past 100 steps: Average Loss 0.184 | Accuracy: 93%
# [Step 28000] Past 100 steps: Average Loss 0.403 | Accuracy: 86%
# [Step 28100] Past 100 steps: Average Loss 0.298 | Accuracy: 91%
# [Step 28200] Past 100 steps: Average Loss 0.163 | Accuracy: 95%
# [Step 28300] Past 100 steps: Average Loss 0.181 | Accuracy: 95%
# [Step 28400] Past 100 steps: Average Loss 0.290 | Accuracy: 91%
# [Step 28500] Past 100 steps: Average Loss 0.231 | Accuracy: 94%
# [Step 28600] Past 100 steps: Average Loss 0.192 | Accuracy: 94%
# [Step 28700] Past 100 steps: Average Loss 0.516 | Accuracy: 84%
# [Step 28800] Past 100 steps: Average Loss 0.286 | Accuracy: 91%
# [Step 28900] Past 100 steps: Average Loss 0.191 | Accuracy: 95%
# [Step 29000] Past 100 steps: Average Loss 0.176 | Accuracy: 96%
# [Step 29100] Past 100 steps: Average Loss 0.219 | Accuracy: 92%
# [Step 29200] Past 100 steps: Average Loss 0.297 | Accuracy: 89%
# [Step 29300] Past 100 steps: Average Loss 0.301 | Accuracy: 93%
# [Step 29400] Past 100 steps: Average Loss 0.071 | Accuracy: 97%
# [Step 29500] Past 100 steps: Average Loss 0.235 | Accuracy: 93%
# [Step 29600] Past 100 steps: Average Loss 0.345 | Accuracy: 91%
# [Step 29700] Past 100 steps: Average Loss 0.199 | Accuracy: 92%
# [Step 29800] Past 100 steps: Average Loss 0.177 | Accuracy: 93%
# [Step 29900] Past 100 steps: Average Loss 0.336 | Accuracy: 90%
# [Step 30000] Past 100 steps: Average Loss 0.522 | Accuracy: 83%
# [Step 30100] Past 100 steps: Average Loss 0.200 | Accuracy: 95%
# [Step 30200] Past 100 steps: Average Loss 0.191 | Accuracy: 94%
# [Step 30300] Past 100 steps: Average Loss 0.103 | Accuracy: 97%
# [Step 30400] Past 100 steps: Average Loss 0.375 | Accuracy: 92%
# [Step 30500] Past 100 steps: Average Loss 0.129 | Accuracy: 97%
# [Step 30600] Past 100 steps: Average Loss 0.107 | Accuracy: 94%
# [Step 30700] Past 100 steps: Average Loss 0.171 | Accuracy: 96%
# [Step 30800] Past 100 steps: Average Loss 0.401 | Accuracy: 90%
# [Step 30900] Past 100 steps: Average Loss 0.271 | Accuracy: 95%
# [Step 31000] Past 100 steps: Average Loss 0.141 | Accuracy: 96%
# [Step 31100] Past 100 steps: Average Loss 0.258 | Accuracy: 93%
# [Step 31200] Past 100 steps: Average Loss 0.086 | Accuracy: 98%
# [Step 31300] Past 100 steps: Average Loss 0.255 | Accuracy: 91%
# [Step 31400] Past 100 steps: Average Loss 0.330 | Accuracy: 91%
# [Step 31500] Past 100 steps: Average Loss 0.282 | Accuracy: 91%
# [Step 31600] Past 100 steps: Average Loss 0.330 | Accuracy: 93%
# [Step 31700] Past 100 steps: Average Loss 0.282 | Accuracy: 88%
# [Step 31800] Past 100 steps: Average Loss 0.287 | Accuracy: 93%
# [Step 31900] Past 100 steps: Average Loss 0.128 | Accuracy: 94%
# [Step 32000] Past 100 steps: Average Loss 0.095 | Accuracy: 96%
# [Step 32100] Past 100 steps: Average Loss 0.310 | Accuracy: 89%
# [Step 32200] Past 100 steps: Average Loss 0.075 | Accuracy: 98%
# [Step 32300] Past 100 steps: Average Loss 0.197 | Accuracy: 95%
# [Step 32400] Past 100 steps: Average Loss 0.081 | Accuracy: 95%
# [Step 32500] Past 100 steps: Average Loss 0.126 | Accuracy: 97%
# [Step 32600] Past 100 steps: Average Loss 0.266 | Accuracy: 94%
# [Step 32700] Past 100 steps: Average Loss 0.251 | Accuracy: 93%
# [Step 32800] Past 100 steps: Average Loss 0.322 | Accuracy: 93%
# [Step 32900] Past 100 steps: Average Loss 0.064 | Accuracy: 98%
# [Step 33000] Past 100 steps: Average Loss 0.152 | Accuracy: 96%
# [Step 33100] Past 100 steps: Average Loss 0.190 | Accuracy: 94%
# [Step 33200] Past 100 steps: Average Loss 0.188 | Accuracy: 94%
# [Step 33300] Past 100 steps: Average Loss 0.256 | Accuracy: 91%
# [Step 33400] Past 100 steps: Average Loss 0.355 | Accuracy: 92%
# [Step 33500] Past 100 steps: Average Loss 0.254 | Accuracy: 92%
# [Step 33600] Past 100 steps: Average Loss 0.500 | Accuracy: 89%
# [Step 33700] Past 100 steps: Average Loss 0.085 | Accuracy: 97%
# [Step 33800] Past 100 steps: Average Loss 0.180 | Accuracy: 95%
# [Step 33900] Past 100 steps: Average Loss 0.103 | Accuracy: 98%
# [Step 34000] Past 100 steps: Average Loss 0.199 | Accuracy: 92%
# [Step 34100] Past 100 steps: Average Loss 0.333 | Accuracy: 93%
# [Step 34200] Past 100 steps: Average Loss 0.336 | Accuracy: 93%
# [Step 34300] Past 100 steps: Average Loss 0.204 | Accuracy: 96%
# [Step 34400] Past 100 steps: Average Loss 0.135 | Accuracy: 97%
# [Step 34500] Past 100 steps: Average Loss 0.194 | Accuracy: 97%
# [Step 34600] Past 100 steps: Average Loss 0.193 | Accuracy: 94%
# [Step 34700] Past 100 steps: Average Loss 0.298 | Accuracy: 91%
# [Step 34800] Past 100 steps: Average Loss 0.378 | Accuracy: 94%
# [Step 34900] Past 100 steps: Average Loss 0.218 | Accuracy: 94%
# [Step 35000] Past 100 steps: Average Loss 0.199 | Accuracy: 95%
# [Step 35100] Past 100 steps: Average Loss 0.187 | Accuracy: 92%
# [Step 35200] Past 100 steps: Average Loss 0.247 | Accuracy: 94%
# [Step 35300] Past 100 steps: Average Loss 0.222 | Accuracy: 95%
# [Step 35400] Past 100 steps: Average Loss 0.452 | Accuracy: 90%
# [Step 35500] Past 100 steps: Average Loss 0.114 | Accuracy: 95%
# [Step 35600] Past 100 steps: Average Loss 0.299 | Accuracy: 96%
# [Step 35700] Past 100 steps: Average Loss 0.259 | Accuracy: 93%
# [Step 35800] Past 100 steps: Average Loss 0.305 | Accuracy: 90%
# [Step 35900] Past 100 steps: Average Loss 0.257 | Accuracy: 92%
# [Step 36000] Past 100 steps: Average Loss 0.299 | Accuracy: 90%
# [Step 36100] Past 100 steps: Average Loss 0.314 | Accuracy: 91%
# [Step 36200] Past 100 steps: Average Loss 0.054 | Accuracy: 98%
# [Step 36300] Past 100 steps: Average Loss 0.272 | Accuracy: 94%
# [Step 36400] Past 100 steps: Average Loss 0.099 | Accuracy: 97%
# [Step 36500] Past 100 steps: Average Loss 0.141 | Accuracy: 96%
# [Step 36600] Past 100 steps: Average Loss 0.223 | Accuracy: 94%
# [Step 36700] Past 100 steps: Average Loss 0.204 | Accuracy: 94%
# [Step 36800] Past 100 steps: Average Loss 0.267 | Accuracy: 96%
# [Step 36900] Past 100 steps: Average Loss 0.318 | Accuracy: 91%
# [Step 37000] Past 100 steps: Average Loss 0.410 | Accuracy: 88%
# [Step 37100] Past 100 steps: Average Loss 0.391 | Accuracy: 90%
# [Step 37200] Past 100 steps: Average Loss 0.219 | Accuracy: 94%
# [Step 37300] Past 100 steps: Average Loss 0.400 | Accuracy: 90%
# [Step 37400] Past 100 steps: Average Loss 0.122 | Accuracy: 96%
# [Step 37500] Past 100 steps: Average Loss 0.191 | Accuracy: 92%
# [Step 37600] Past 100 steps: Average Loss 0.197 | Accuracy: 96%
# [Step 37700] Past 100 steps: Average Loss 0.236 | Accuracy: 93%
# [Step 37800] Past 100 steps: Average Loss 0.219 | Accuracy: 95%
# [Step 37900] Past 100 steps: Average Loss 0.289 | Accuracy: 92%
# [Step 38000] Past 100 steps: Average Loss 0.185 | Accuracy: 93%
# [Step 38100] Past 100 steps: Average Loss 0.154 | Accuracy: 93%
# [Step 38200] Past 100 steps: Average Loss 0.354 | Accuracy: 96%
# [Step 38300] Past 100 steps: Average Loss 0.091 | Accuracy: 97%
# [Step 38400] Past 100 steps: Average Loss 0.356 | Accuracy: 91%
# [Step 38500] Past 100 steps: Average Loss 0.148 | Accuracy: 96%
# [Step 38600] Past 100 steps: Average Loss 0.184 | Accuracy: 91%
# [Step 38700] Past 100 steps: Average Loss 0.300 | Accuracy: 95%
# [Step 38800] Past 100 steps: Average Loss 0.085 | Accuracy: 95%
# [Step 38900] Past 100 steps: Average Loss 0.445 | Accuracy: 89%
# [Step 39000] Past 100 steps: Average Loss 0.397 | Accuracy: 89%
# [Step 39100] Past 100 steps: Average Loss 0.195 | Accuracy: 94%
# [Step 39200] Past 100 steps: Average Loss 0.379 | Accuracy: 92%
# [Step 39300] Past 100 steps: Average Loss 0.169 | Accuracy: 94%
# [Step 39400] Past 100 steps: Average Loss 0.171 | Accuracy: 96%
# [Step 39500] Past 100 steps: Average Loss 0.073 | Accuracy: 96%
# [Step 39600] Past 100 steps: Average Loss 0.204 | Accuracy: 96%
# [Step 39700] Past 100 steps: Average Loss 0.178 | Accuracy: 96%
# [Step 39800] Past 100 steps: Average Loss 0.318 | Accuracy: 90%
# [Step 39900] Past 100 steps: Average Loss 0.352 | Accuracy: 91%
# [Step 40000] Past 100 steps: Average Loss 0.192 | Accuracy: 95%
# [Step 40100] Past 100 steps: Average Loss 0.491 | Accuracy: 91%
# [Step 40200] Past 100 steps: Average Loss 0.130 | Accuracy: 95%
# [Step 40300] Past 100 steps: Average Loss 0.168 | Accuracy: 94%
# [Step 40400] Past 100 steps: Average Loss 0.509 | Accuracy: 90%
# [Step 40500] Past 100 steps: Average Loss 0.238 | Accuracy: 93%
# [Step 40600] Past 100 steps: Average Loss 0.341 | Accuracy: 90%
# [Step 40700] Past 100 steps: Average Loss 0.265 | Accuracy: 92%
# [Step 40800] Past 100 steps: Average Loss 0.219 | Accuracy: 95%
# [Step 40900] Past 100 steps: Average Loss 0.209 | Accuracy: 93%
# [Step 41000] Past 100 steps: Average Loss 0.383 | Accuracy: 90%
# [Step 41100] Past 100 steps: Average Loss 0.178 | Accuracy: 96%
# [Step 41200] Past 100 steps: Average Loss 0.195 | Accuracy: 93%
# [Step 41300] Past 100 steps: Average Loss 0.561 | Accuracy: 88%
# [Step 41400] Past 100 steps: Average Loss 0.498 | Accuracy: 92%
# [Step 41500] Past 100 steps: Average Loss 0.300 | Accuracy: 91%
# [Step 41600] Past 100 steps: Average Loss 0.190 | Accuracy: 91%
# [Step 41700] Past 100 steps: Average Loss 0.224 | Accuracy: 94%
# [Step 41800] Past 100 steps: Average Loss 0.377 | Accuracy: 94%
# [Step 41900] Past 100 steps: Average Loss 0.266 | Accuracy: 93%
# [Step 42000] Past 100 steps: Average Loss 0.227 | Accuracy: 94%
# ----EPOCH 3 ---
# [Step 100] Past 100 steps: Average Loss 0.401 | Accuracy: 87%
# [Step 200] Past 100 steps: Average Loss 0.435 | Accuracy: 88%
# [Step 300] Past 100 steps: Average Loss 0.293 | Accuracy: 93%
# [Step 400] Past 100 steps: Average Loss 0.069 | Accuracy: 98%
# [Step 500] Past 100 steps: Average Loss 0.398 | Accuracy: 91%
# [Step 600] Past 100 steps: Average Loss 0.229 | Accuracy: 94%
# [Step 700] Past 100 steps: Average Loss 0.450 | Accuracy: 86%
# [Step 800] Past 100 steps: Average Loss 0.075 | Accuracy: 97%
# [Step 900] Past 100 steps: Average Loss 0.320 | Accuracy: 90%
# [Step 1000] Past 100 steps: Average Loss 0.035 | Accuracy: 99%
# [Step 1100] Past 100 steps: Average Loss 0.177 | Accuracy: 95%
# [Step 1200] Past 100 steps: Average Loss 0.223 | Accuracy: 90%
# [Step 1300] Past 100 steps: Average Loss 0.120 | Accuracy: 96%
# [Step 1400] Past 100 steps: Average Loss 0.235 | Accuracy: 95%
# [Step 1500] Past 100 steps: Average Loss 0.112 | Accuracy: 97%
# [Step 1600] Past 100 steps: Average Loss 0.202 | Accuracy: 94%
# [Step 1700] Past 100 steps: Average Loss 0.228 | Accuracy: 94%
# [Step 1800] Past 100 steps: Average Loss 0.428 | Accuracy: 94%
# [Step 1900] Past 100 steps: Average Loss 0.199 | Accuracy: 95%
# [Step 2000] Past 100 steps: Average Loss 0.349 | Accuracy: 90%
# [Step 2100] Past 100 steps: Average Loss 0.097 | Accuracy: 97%
# [Step 2200] Past 100 steps: Average Loss 0.358 | Accuracy: 92%
# [Step 2300] Past 100 steps: Average Loss 0.319 | Accuracy: 93%
# [Step 2400] Past 100 steps: Average Loss 0.576 | Accuracy: 85%
# [Step 2500] Past 100 steps: Average Loss 0.270 | Accuracy: 92%
# [Step 2600] Past 100 steps: Average Loss 0.316 | Accuracy: 92%
# [Step 2700] Past 100 steps: Average Loss 0.189 | Accuracy: 94%
# [Step 2800] Past 100 steps: Average Loss 0.384 | Accuracy: 89%
# [Step 2900] Past 100 steps: Average Loss 0.076 | Accuracy: 97%
# [Step 3000] Past 100 steps: Average Loss 0.568 | Accuracy: 87%
# [Step 3100] Past 100 steps: Average Loss 0.222 | Accuracy: 92%
# [Step 3200] Past 100 steps: Average Loss 0.186 | Accuracy: 97%
# [Step 3300] Past 100 steps: Average Loss 0.120 | Accuracy: 96%
# [Step 3400] Past 100 steps: Average Loss 0.429 | Accuracy: 89%
# [Step 3500] Past 100 steps: Average Loss 0.061 | Accuracy: 98%
# [Step 3600] Past 100 steps: Average Loss 0.400 | Accuracy: 89%
# [Step 3700] Past 100 steps: Average Loss 0.388 | Accuracy: 92%
# [Step 3800] Past 100 steps: Average Loss 0.464 | Accuracy: 89%
# [Step 3900] Past 100 steps: Average Loss 0.228 | Accuracy: 96%
# [Step 4000] Past 100 steps: Average Loss 0.136 | Accuracy: 98%
# [Step 4100] Past 100 steps: Average Loss 0.122 | Accuracy: 97%
# [Step 4200] Past 100 steps: Average Loss 0.143 | Accuracy: 97%
# [Step 4300] Past 100 steps: Average Loss 0.233 | Accuracy: 94%
# [Step 4400] Past 100 steps: Average Loss 0.206 | Accuracy: 94%
# [Step 4500] Past 100 steps: Average Loss 0.300 | Accuracy: 89%
# [Step 4600] Past 100 steps: Average Loss 0.157 | Accuracy: 95%
# [Step 4700] Past 100 steps: Average Loss 0.391 | Accuracy: 92%
# [Step 4800] Past 100 steps: Average Loss 0.144 | Accuracy: 94%
# [Step 4900] Past 100 steps: Average Loss 0.309 | Accuracy: 93%
# [Step 5000] Past 100 steps: Average Loss 0.291 | Accuracy: 92%
# [Step 5100] Past 100 steps: Average Loss 0.336 | Accuracy: 96%
# [Step 5200] Past 100 steps: Average Loss 0.283 | Accuracy: 96%
# [Step 5300] Past 100 steps: Average Loss 0.129 | Accuracy: 96%
# [Step 5400] Past 100 steps: Average Loss 0.432 | Accuracy: 88%
# [Step 5500] Past 100 steps: Average Loss 0.167 | Accuracy: 94%
# [Step 5600] Past 100 steps: Average Loss 0.116 | Accuracy: 96%
# [Step 5700] Past 100 steps: Average Loss 0.288 | Accuracy: 96%
# [Step 5800] Past 100 steps: Average Loss 0.280 | Accuracy: 92%
# [Step 5900] Past 100 steps: Average Loss 0.336 | Accuracy: 91%
# [Step 6000] Past 100 steps: Average Loss 0.396 | Accuracy: 92%
# [Step 6100] Past 100 steps: Average Loss 0.117 | Accuracy: 95%
# [Step 6200] Past 100 steps: Average Loss 0.491 | Accuracy: 88%
# [Step 6300] Past 100 steps: Average Loss 0.435 | Accuracy: 91%
# [Step 6400] Past 100 steps: Average Loss 0.209 | Accuracy: 96%
# [Step 6500] Past 100 steps: Average Loss 0.120 | Accuracy: 97%
# [Step 6600] Past 100 steps: Average Loss 0.435 | Accuracy: 94%
# [Step 6700] Past 100 steps: Average Loss 0.413 | Accuracy: 89%
# [Step 6800] Past 100 steps: Average Loss 0.249 | Accuracy: 97%
# [Step 6900] Past 100 steps: Average Loss 0.429 | Accuracy: 91%
# [Step 7000] Past 100 steps: Average Loss 0.252 | Accuracy: 91%
# [Step 7100] Past 100 steps: Average Loss 0.175 | Accuracy: 95%
# [Step 7200] Past 100 steps: Average Loss 0.330 | Accuracy: 89%
# [Step 7300] Past 100 steps: Average Loss 0.331 | Accuracy: 90%
# [Step 7400] Past 100 steps: Average Loss 0.238 | Accuracy: 92%
# [Step 7500] Past 100 steps: Average Loss 0.334 | Accuracy: 94%
# [Step 7600] Past 100 steps: Average Loss 0.600 | Accuracy: 88%
# [Step 7700] Past 100 steps: Average Loss 0.480 | Accuracy: 89%
# [Step 7800] Past 100 steps: Average Loss 0.344 | Accuracy: 92%
# [Step 7900] Past 100 steps: Average Loss 0.197 | Accuracy: 92%
# [Step 8000] Past 100 steps: Average Loss 0.312 | Accuracy: 93%
# [Step 8100] Past 100 steps: Average Loss 0.227 | Accuracy: 94%
# [Step 8200] Past 100 steps: Average Loss 0.411 | Accuracy: 90%
# [Step 8300] Past 100 steps: Average Loss 0.189 | Accuracy: 94%
# [Step 8400] Past 100 steps: Average Loss 0.198 | Accuracy: 95%
# [Step 8500] Past 100 steps: Average Loss 0.260 | Accuracy: 95%
# [Step 8600] Past 100 steps: Average Loss 0.013 | Accuracy: 100%
# [Step 8700] Past 100 steps: Average Loss 0.421 | Accuracy: 91%
# [Step 8800] Past 100 steps: Average Loss 0.303 | Accuracy: 91%
# [Step 8900] Past 100 steps: Average Loss 0.244 | Accuracy: 91%
# [Step 9000] Past 100 steps: Average Loss 0.146 | Accuracy: 95%
# [Step 9100] Past 100 steps: Average Loss 0.085 | Accuracy: 98%
# [Step 9200] Past 100 steps: Average Loss 0.093 | Accuracy: 98%
# [Step 9300] Past 100 steps: Average Loss 0.065 | Accuracy: 98%
# [Step 9400] Past 100 steps: Average Loss 0.230 | Accuracy: 94%
# [Step 9500] Past 100 steps: Average Loss 0.361 | Accuracy: 92%
# [Step 9600] Past 100 steps: Average Loss 0.315 | Accuracy: 93%
# [Step 9700] Past 100 steps: Average Loss 0.035 | Accuracy: 99%
# [Step 9800] Past 100 steps: Average Loss 0.396 | Accuracy: 89%

# %%
result = model.predict(testing_images)
test_labels = []
for i in result:
    for j in range(len(i)):
        if i[j] == max(i):
            test_labels.append(j)

# %%
fh = open('E:/Curious Dev B/Kaggle/results - Digit Recogniser(24).csv', 'w')
ct = 0
for i in test_labels:
    ct += 1
    fstr = str(ct)+','+str(i)+','+'\n'
    fh.write(fstr)

# %%
from IPython.display import display
from PIL import Image
testing_images.shape = (28000, 28, 28)
for i in testing_images[27900:]:
    img = Image.fromarray(np.uint8((i)*255))
    display(img)
